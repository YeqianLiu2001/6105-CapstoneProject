# %% [markdown]
# ### Dataset Reference:
#
# Guo, S., Lin, Y., Feng, N., Song, C., & Wan, H. (2019). Attention Based Spatial-Temporal Graph Convolutional Networks for Traffic Flow Forecasting. Proceedings of the AAAI Conference on Artificial Intelligence, 33(01), 922-929. https://doi.org/10.1609/aaai.v33i01.3301922

# %% [markdown]
# ### Additional Reference:
#
# ChatGPT is used for debugging, clarification of concepts, and the writing of comments and descriptions.

# %% [markdown]
# <a id="contents"></a>
# # Table of Content
# 1. [Problem Introduction](#section-1)
# 2. [Import Libraries & Initialize Plots](#section-2)
# 3. [Data Formatting](#section-3)
# 4. [Data Visualization & EDA](#section-4)
# 5. [Data Preparation](#section-5)
# 6. [Train Model](#section-6)
# 7. [Evaluate Prediction](#section-7)
# 8. [Conclusion](#section-8)

# %% [markdown]
# <a id="section-1"></a>
# # Problem Introduction

# %% [markdown]
# We've come across an intriguing traffic dataset, PEMS-08 Dataset, which encompasses traffic data in San Bernardino from July to August in 2016. It comprises 170 locations equipped with detectors capturing traffic information at 5-minute intervals. The dataset entails 3 features: flow, occupancy, and speed. Let's delve into the specifics of these features:
#
# - **Flow**: Represents the number of vehicles passing through the loop detector per 5-minute interval.
# - **Occupancy**: Reflects the proportion of time during the 5-minute interval that the detector was occupied by a vehicle, measured as a percentage.
# - **Speed**: Indicates the average speed of vehicles traversing the loop detector during the 5-minute interval, measured in miles per hour (mph).
#
# Inspired by this dataset, we've posed an intriguing question: What if we devise a model capable of predicting and ranking locations with the highest traffic volume? We believe such a predictive task could aid law enforcement in identifying optimal patrol locations based on specific times. To simplify the problem, we'll leverage occupancy as our target variable, assuming it encapsulates estimated traffic levels at a given time.
#
# Formally, we've articulated the following problem statement: For prediction of the occupancy variable across locations, construct a predictive model to minimize RMSE, where RMSE is the root mean square error, and to optimize Spearman's rank correlation coefficient (ρ), quantifying the correlation between predicted and actual occupancy ranks.
#
# Spearman's correlation coefficient evaluates the strength and direction of the monotonic relationship between two variables. Since we aim to focus on optimizing patrol location selection, Spearman's ρ is ideal as it considers the relative ranking of variables rather than their absolute values.
#
# Our current approach involves initially minimizing RMSE for predicting actual occupancy values, while leveraging the rank of values. To achieve this, we'll train an LSTM model and utilize the moving average of previous occupancy values as the baseline.

# %% [markdown]
# <a id="section-2"></a>
# # Import Libraries & Initialize Plots

# %% [markdown]
# As always, we will first import all the libraries necessary for this notebook to run. We put all the imports at the top to make it easier to check the dependencies.

# %%
# Common libraries for data cleaning and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from numpy import load # use to load an npz file
from scipy.signal import periodogram # use to graph a periodogram to get seasonality analysis
from sklearn.preprocessing import MinMaxScaler # use to normalize the data features

# keras library to create NN models
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# libraries for the metrics we will use (RMSE and Spearman)
from keras.metrics import RootMeanSquaredError
import scipy.stats as stats

# %% [markdown]
# In addition, we changed the notebook default plotting settings to make the graph prettier.

# %%
# Set plot settings
plt.rcParams.update({'font.size': 12, 'font.family': 'serif'})
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.grid.which'] = 'both'
plt.rcParams['grid.alpha'] = 0.5

# %% [markdown]
# <a id="section-3"></a>
# # Data Formatting

# %% [markdown]
# Interestingly, the data is in the format of npz. npz is a file format used by the NumPy library to store arrays and metadata in a compressed format. We will first convert it to pandas dataframe, since we are more familiar with it.

# %%
file_path = 'C:/Users/liuyeqian/Downloads/pems08.npz'  
data = load(file_path)

# %%
lst = data.files
print(data[lst[0]].shape)
print(data[lst[0]])
# Out:
# (17856, 170, 3)
# [[[1.330e+02 6.030e-02 6.580e+01]
#   [2.100e+02 5.890e-02 6.960e+01]
#   [1.240e+02 3.580e-02 6.580e+01]
#   ...
#   [7.400e+01 2.131e-01 6.530e+01]
#   [9.400e+01 2.260e-02 6.800e+01]
#   [6.000e+00 3.100e-03 6.500e+01]]
#
#  [[1.140e+02 5.320e-02 6.690e+01]
#   [1.850e+02 5.500e-02 6.850e+01]
#   [1.190e+02 3.390e-02 6.500e+01]
#   ...
#   [7.300e+01 1.469e-01 3.720e+01]
#   [8.400e+01 1.890e-02 6.870e+01]
#   [4.000e+00 1.800e-03 6.500e+01]]
#
#  [[1.400e+02 6.220e-02 6.680e+01]
#   [1.710e+02 4.660e-02 6.990e+01]
#   [1.070e+02 3.360e-02 6.380e+01]
#   ...
#   [7.000e+01 5.860e-02 3.400e+01]
#   [8.200e+01 2.200e-02 6.700e+01]
#   [4.000e+00 2.100e-03 6.490e+01]]
#
#  ...
#
#  [[1.200e+02 5.810e-02 6.330e+01]
#   [1.760e+02 5.290e-02 6.680e+01]
#   [1.190e+02 5.180e-02 5.610e+01]
#   ...
#   [4.700e+01 1.551e-01 3.220e+01]
#   [9.100e+01 2.290e-02 6.640e+01]
#   [3.000e+00 1.400e-03 6.530e+01]]
#
#  [[1.020e+02 5.790e-02 6.140e+01]
#   [1.650e+02 4.920e-02 6.720e+01]
#   [1.330e+02 5.070e-02 5.890e+01]
#   ...
#   [9.700e+01 1.265e-01 3.080e+01]
#   [8.500e+01 2.080e-02 6.750e+01]
#   [2.000e+00 1.000e-03 6.520e+01]]
#
#  [[1.020e+02 5.650e-02 6.170e+01]
#   [1.660e+02 5.020e-02 6.760e+01]
#   [1.330e+02 4.640e-02 5.630e+01]
#   ...
#   [8.300e+01 2.730e-02 5.910e+01]
#   [7.000e+01 1.880e-02 6.660e+01]
#   [6.000e+00 2.600e-03 6.520e+01]]]

# %% [markdown]
# The file gives a numpy array with dimensions (17856, 170, 3), which are in the form of (timesteps, location, features). For the 3 features, the order is `flow`,`occupy`,`speed`.

# %%
traffic_data = data[lst[0]]
data_dict = []
# loop for every timestep and every location and add as a single row
for timestep in range(traffic_data.shape[0]):
    for location in range(traffic_data.shape[1]):
        data_dict.append({
            "timestep" : timestep+1,
            "location" : location,
            "flow"     : traffic_data[timestep][location][0],
            "occupy"   : traffic_data[timestep][location][1],
            "speed"    : traffic_data[timestep][location][2]
        })

# %% [markdown]
# We changed it into a list of dictionary. Each row represents a single timestep in a single location.

# %%
df = pd.DataFrame(data_dict)
df.to_csv("traffic.csv", index=False)

# %% [markdown]
# Finally, we save it into a csv file called `traffic.csv`.

# %% [markdown]
# <a id="section-4"></a>
# # Data Visualization & EDA

# %% [markdown]
# Now it is time for Data Visualization and Exploratory Data Analysis. Here, we will see through the data and clean and apply feature engineering when necessary.

# %%
traffic = pd.read_csv("traffic.csv")
print(len(traffic))
traffic.head()
# Out:
# 3035520
#    timestep  location   flow  occupy  speed
# 0         1         0  133.0  0.0603   65.8
# 1         1         1  210.0  0.0589   69.6
# 2         1         2  124.0  0.0358   65.8
# 3         1         3  145.0  0.0416   69.6
# 4         1         4  206.0  0.0493   69.4

# %% [markdown]
# The data consist of $17856 \cdot 170 = 3035520$ rows. That is a lot of rows! We will have to handle that later, but for now, let us look into the data.

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035520 entries, 0 to 3035519
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   timestep  int64
#  1   location  int64
#  2   flow      float64
#  3   occupy    float64
#  4   speed     float64
# dtypes: float64(3), int64(2)
# memory usage: 115.8 MB

# %% [markdown]
# All of the data seem to be either integer or float, nothing out of the ordinarily here. `flow`, `occupy` and `speed` are numerical and continuous data.

# %%
traffic.count()
# Out:
# timestep    3035520
# location    3035520
# flow        3035520
# occupy      3035520
# speed       3035520
# dtype: int64

# %%
traffic.isna().sum()
# Out:
# timestep    0
# location    0
# flow        0
# occupy      0
# speed       0
# dtype: int64

# %% [markdown]
# Also nothing surprising here, and fortunately the data has no null values, so we don't need to impute any values.

# %%
traffic.describe()
# Out:
#            timestep      location          flow        occupy         speed
# count  3.035520e+06  3.035520e+06  3.035520e+06  3.035520e+06  3.035520e+06
# mean   8.928500e+03  8.450000e+01  2.306807e+02  6.507109e-02  6.376300e+01
# std    5.154584e+03  4.907393e+01  1.462170e+02  4.590215e-02  6.652010e+00
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  3.000000e+00
# 25%    4.464750e+03  4.200000e+01  1.100000e+02  3.570000e-02  6.260000e+01
# 50%    8.928500e+03  8.450000e+01  2.150000e+02  6.010000e-02  6.490000e+01
# 75%    1.339225e+04  1.270000e+02  3.340000e+02  8.390000e-02  6.740000e+01
# max    1.785600e+04  1.690000e+02  1.147000e+03  8.955000e-01  8.230000e+01

# %%
traffic['flow'].hist(bins=100);

# %%
traffic['occupy'].hist(bins=100);

# %%
traffic['speed'].hist(bins=100);

# %% [markdown]
# Looking at the distribution of `flow`, `occupy` and `speed`, it looks like they are spread out nicely and roughly follows a nice (a bit skewed) normal distribution. However, one thing to note is that the order of magnitude of the values are quite different, so we should normalize and scale the data later.

# %% [markdown]
# Now, we would like to explore the data further. For this, we will choose a single random location.

# %%
location_0 = traffic[traffic["location"]==50].reset_index()
location_0.head()
# Out:
#    index  timestep  location  flow  occupy  speed
# 0     50         1        50  76.0  0.0262   69.5
# 1    220         2        50  81.0  0.0255   68.8
# 2    390         3        50  80.0  0.0243   69.0
# 3    560         4        50  76.0  0.0255   68.4
# 4    730         5        50  70.0  0.0224   68.1

# %%
location_0["occupy"][:1000].plot()
# Out:
# <Axes: >

# %%
location_0["flow"][:1000].plot()
# Out:
# <Axes: >

# %%
location_0["speed"][:1000].plot();

# %% [markdown]
# We limit the plot to the first 1000 values since there are too many timesteps and the plot will be hard to look and analyze. From the plot above (and checking some other random locations), there seem to be a strong seasonality on `flow` and more importantly `occupy` , which is out target variable.

# %% [markdown]
# Of course in any time series prediction, lag features are used as the main features. Specifically, $k$ lag features means that we use the last $k$ values to predict the next value. So, it is a good measure to check the correlation of present $(t_n)$ and future $(t_{n+1})$ values

# %%
COR_STEP = 1
pres = traffic[['flow', 'occupy', 'speed']][0:-(COR_STEP)].reset_index(drop=True)
future = traffic[['flow', 'occupy', 'speed']][COR_STEP:] \
    .reset_index(drop=True) \
    .add_suffix('_future')
val = pres.join(future)
val.corr()
# Out:
#                    flow    occupy     speed  flow_future  occupy_future  \
# flow           1.000000  0.674039 -0.296332     0.535235       0.450192
# occupy         0.674039  1.000000 -0.752040     0.445282       0.477379
# speed         -0.296332 -0.752040  1.000000    -0.228266      -0.275180
# flow_future    0.535235  0.445282 -0.228266     1.000000       0.674040
# occupy_future  0.450192  0.477379 -0.275180     0.674040       1.000000
# speed_future  -0.235030 -0.303858  0.233537    -0.296331      -0.752040
#
#                speed_future
# flow              -0.235030
# occupy            -0.303858
# speed              0.233537
# flow_future       -0.296331
# occupy_future     -0.752040
# speed_future       1.000000

# %% [markdown]
# From this (and some other locations we check), we can see that the correlation of all the variables to occupy is moderately high. (It might not look that high, but considering that we can use multiple steps of lag features, it is a pretty good correlation.) In addition, it is also nice to see that the correlation of `flow` and `speed` to `occupy` is also high, which suggests that the variables might be linearly correlated and could be used to predict each other.

# %%
def plot_periodogram(ts, detrend='linear', ax=None):
    """
    Plots the periodogram of a time series.

    Args:
        ts (pd.Series): A time series.
        detrend (str): Detrending method for the time series.
        ax (matplotlib.axes.Axes): The axes on which to plot.

    Returns:
        ax (matplotlib.axes.Axes): The axes on which the periodogram is plotted.
    """
    fs = pd.Timedelta(weeks=4) / pd.Timedelta(minutes=5)
    frequencies, spectrum = periodogram(
        ts,
        fs=fs,
        detrend=detrend,
        window="boxcar",
        scaling='spectrum',
    )
    if ax is None:
        _, ax = plt.subplots()
        
    ax.step(frequencies, spectrum, color="purple")
    ax.set_xscale("log")
    ax.set_xticks([4, 30, 30*24])
    ax.set_xticklabels(
        [
            "Weekly",
            "Daily",
            "Hourly"
        ],
        rotation=30,
    )
    ax.ticklabel_format(axis="y", style="sci", scilimits=(0, 0))
    ax.set_ylabel("Variance")
    ax.set_title("Periodogram")
    return ax
location_0 = traffic[traffic["location"]==50].reset_index()
plot_periodogram(location_0["occupy"])
# Out:
# <Axes: title={'center': 'Periodogram'}, ylabel='Variance'>

# %% [markdown]
# Here, we graph a [periodogram](https://en.wikipedia.org/wiki/Periodogram) to test the seasonality of the `occupy` variable. The periodogram shows the strength of the frequencies present in the time series, and can be used to identify the dominant frequencies or periodicities in the data. From the graph above, it suggests that there seem to be a pattern in the occupy variable daily, which makes sense, since many people work and travel on a fixed schedule. (for example busy hours after work will have higher traffic) For this reason, we will add an `hour` feature on prediction.

# %% [markdown]
# As said earlier, the number of rows in this is pretty large (and when we tried add >10 lag features, the memory limit exceeded >8gb). So, we will instead be working on hourly timesteps instead of 5 minutes interval. The data within an hour (12 5-minute timesteps) will be averaged.

# %%
location_0["hour"] = ((location_0["timestep"] - 1) // 12)
grouped = location_0.groupby("hour").mean().reset_index()
grouped.head()
# Out:
#    hour   index  timestep  location       flow    occupy      speed
# 0     0   985.0       6.5      50.0  65.500000  0.021700  68.191667
# 1     1  3025.0      18.5      50.0  48.166667  0.016567  67.900000
# 2     2  5065.0      30.5      50.0  41.166667  0.016350  67.691667
# 3     3  7105.0      42.5      50.0  46.666667  0.019350  67.591667
# 4     4  9145.0      54.5      50.0  89.750000  0.031800  68.141667

# %%
grouped["occupy"][:24*5].plot();

# %%
COR_STEP = 12
pres = grouped[['flow', 'occupy', 'speed']][0:-(COR_STEP)].reset_index(drop=True)
future = grouped[['flow', 'occupy', 'speed']][COR_STEP:] \
    .reset_index(drop=True) \
    .add_suffix('_future')
val = pres.join(future)
val.corr()
# Out:
#                    flow    occupy     speed  flow_future  occupy_future  \
# flow           1.000000  0.966218 -0.718619    -0.722547      -0.707590
# occupy         0.966218  1.000000 -0.839110    -0.707282      -0.694619
# speed         -0.718619 -0.839110  1.000000     0.693508       0.681356
# flow_future   -0.722547 -0.707282  0.693508     1.000000       0.966046
# occupy_future -0.707590 -0.694619  0.681356     0.966046       1.000000
# speed_future   0.701991  0.686046 -0.599727    -0.718996      -0.839682
#
#                speed_future
# flow               0.701991
# occupy             0.686046
# speed             -0.599727
# flow_future       -0.718996
# occupy_future     -0.839682
# speed_future       1.000000

# %% [markdown]
# After merging the timesteps, we get a higher correlation with future values, which is nice.

# %% [markdown]
# <a id="section-5"></a>
# # Data Preparation

# %% [markdown]
# Now that we are done with the EDA, it is time to prepare our data for prediction. We add the features we found useful from the EDA. We also normalize and split our data to train and test datasets.

# %%
# creating 3-dimensional array for [timestep, timeframe, features]
def create_dataset(location, WINDOW_SIZE):
    
    # mask a certain location
    location_current = traffic[traffic["location"]==location].reset_index()
    
    # group to hour and average 12 (5-minute) timesteps
    location_current["hour"] = ((location_current["timestep"] - 1) // 12)
    grouped = location_current.groupby("hour").mean().reset_index()
    
    # add hour features as mod 24 cycle (0...23)
    grouped['day'] = (grouped['hour'] // 24) % 7
    grouped['hour'] %= 24
    
    one_hot_hour = pd.get_dummies(grouped['hour'])
    one_hot_hour = one_hot_hour.add_prefix('hour_')
    
    # merge all the features together to get a total of 27 features
    hour_grouped = pd.concat([grouped[["occupy", "flow", "speed"]], one_hot_hour], axis=1)
    hour_grouped = np.array(hour_grouped)
    
    X, Y = [], []
    
    # add lag features (in reverse time order)
    for i in range(len(hour_grouped) - WINDOW_SIZE):
        X.append(hour_grouped[i:(i + WINDOW_SIZE)][::-1]) # reverse the order
        Y.append(hour_grouped[i + WINDOW_SIZE, 0]) # index 0 is occupy
    
    return X,Y # returns (timestep, timeframe, features) and (target)

# %% [markdown]
# We make a `create_dataset` function to make all the features that we need for the prediction (hour features and lag features as multiple dimensions). Each lag step (lag steps total of WINDOW_SIZE) will be included to X in the second dimension (in reverse order). We format the array X as dimension (timestep, timeframe, features) and Y as dimension (target).

# %% [markdown]
# Our choice for WINDOW_SIZE is 24. Using too low would hinder us from fully utilizing the LSTM layer which reduces overall accuracy, while using too high poses the model to thee vanishing gradient issue (the diminishing updates in earlier layers of a deep neural network during training, caused by small gradients, which can lead to slow or stalled learning) and increases the memory requirement.

# %%
# creating 4-th dimension for the locations
X, Y = [], []

for location in range(170):
    a,b = create_dataset(location, WINDOW_SIZE=24)
    X.append(a)
    Y.append(b)
    
X = np.moveaxis(X,0,-1)
Y = np.moveaxis(Y,0,-1)

print(X.shape)
print(Y.shape)
# Out:
# (1464, 24, 27, 170)
# (1464, 170)

# %% [markdown]
# Finally here, we merge all the locations together to get X `(timestep, timeframe, features, location)` and Y `(timestep, location)`.

# %%
TRAIN_SIZE = 0.8
TEST_SIZE  = 0.2

train_size = int(len(X) * TRAIN_SIZE)
test_size  = int(len(X) * TEST_SIZE)

train_X, train_Y = X[:train_size], Y[:train_size]
test_X, test_Y = X[train_size:], Y[train_size:]

print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# (1171, 24, 27, 170)
# (1171, 170)
# (293, 24, 27, 170)
# (293, 170)

# %% [markdown]
# Here, we split the data into train and test with `train : test` ratio of `0.8 : 0.2`. In a time series analysis, we don't usually use random splitting because it wont make sense to predict data in gaps, so we split the first 80% as train while the last 20% is used as test set.

# %%
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler()
train_X = scaler_X.fit_transform(train_X.reshape(train_X.shape[0] * train_X.shape[1], -1)) \
                   .reshape(train_X.shape[0], train_X.shape[1], -1)
test_X = scaler_X.transform(test_X.reshape(test_X.shape[0] * test_X.shape[1], -1)) \
                   .reshape(test_X.shape[0], test_X.shape[1], -1)
train_Y = scaler_Y.fit_transform(train_Y)
test_Y = scaler_Y.transform(test_Y)

# %% [markdown]
# Then, we apply a `MinMaxScaler` to scale both X and Y features to the range (0,1). (Note that we need to use a different scaler for X and Y. Also, the good practice is to not fit using test since we assume that it is a fresh data and we have no information about it, so we only using train split to fit the scaler.

# %%
print(train_X.shape)
print(test_X.shape)
print(train_Y.shape)
print(test_Y.shape)
# Out:
# (1171, 24, 4590)
# (293, 24, 4590)
# (1171, 170)
# (293, 170)

# %% [markdown]
# Note that the shape changed a bit for X. I reshaped it so that the dimensions are `(timestep, timeframe, features*location)`. (we merged the locations together so that the final dimensions have features for every 170 locations.)

# %% [markdown]
# <a id="section-6"></a>
# # Model Training

# %% [markdown]
# Finally, the exciting part! We get to see our prediction model in action. We will use an LSTM layer as the input layer while we will output a vector of 170 values, each one to predict the value of `occupy` of each location.
#
# The reason we used an LSTM layer is because the LSTM is built to remember information from earlier timesteps and gain information from their relation.
#
# We will use `MSE` for the loss and `RMSE` as the metric. (metric will not be used for backpropagation and only serve to look at how well the prediction is at that iteration)
#
# Also, we use `ReLu` since our task is a regression task.

# %%
model = Sequential([
    LSTM(256, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])),
    LSTM(256, return_sequences=False),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(170, activation='linear'),
])

model.compile(loss='mse', optimizer='adam', metrics=[RootMeanSquaredError()])
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 24, 256)             │       4,963,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 170)                 │          43,690 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,598,122 (21.36 MB)
#  Trainable params: 5,598,122 (21.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from keras.utils.vis_utils import plot_modelfr
#       2 plot_model(model, show_shapes=True, show_layer_names=True)
#
# ModuleNotFoundError: No module named 'keras.utils.vis_utils'

# %% [markdown]
# Once the model architecture is set, it is time to train the model. We can tune the hyperparemeters: epoch (the number of training iterations) and batch_size (the number of rows to include in a single forward and backpropagation). We will include validation split of 0.1 (by default it will take 10% of the last few rows and use it as validation data, which is not used for training but we can use it to evaluate on an unseen data for every given step).

# %%
# Train the model
history = model.fit(train_X, train_Y, epochs=150, batch_size=32, validation_split=0.1, verbose=2)
# Out:
# Epoch 1/150
# 33/33 - 12s - 352ms/step - loss: 0.0425 - root_mean_squared_error: 0.2061 - val_loss: 0.0201 - val_root_mean_squared_error: 0.1418
# Epoch 2/150
# 33/33 - 8s - 243ms/step - loss: 0.0153 - root_mean_squared_error: 0.1239 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 3/150
# 33/33 - 8s - 241ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1182
# Epoch 4/150
# 33/33 - 8s - 241ms/step - loss: 0.0118 - root_mean_squared_error: 0.1088 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 5/150
# 33/33 - 8s - 242ms/step - loss: 0.0112 - root_mean_squared_error: 0.1057 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 6/150
# 33/33 - 8s - 241ms/step - loss: 0.0106 - root_mean_squared_error: 0.1028 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1065
# Epoch 7/150
# 33/33 - 8s - 241ms/step - loss: 0.0084 - root_mean_squared_error: 0.0914 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 8/150
# 33/33 - 8s - 241ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0972
# Epoch 9/150
# 33/33 - 8s - 239ms/step - loss: 0.0065 - root_mean_squared_error: 0.0809 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 10/150
# 33/33 - 8s - 242ms/step - loss: 0.0061 - root_mean_squared_error: 0.0784 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0953
# Epoch 11/150
# 33/33 - 8s - 240ms/step - loss: 0.0060 - root_mean_squared_error: 0.0772 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0934
# Epoch 12/150
# 33/33 - 8s - 239ms/step - loss: 0.0056 - root_mean_squared_error: 0.0750 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 13/150
# 33/33 - 8s - 246ms/step - loss: 0.0055 - root_mean_squared_error: 0.0743 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0941
# Epoch 14/150
# 33/33 - 8s - 246ms/step - loss: 0.0054 - root_mean_squared_error: 0.0734 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0953
# Epoch 15/150
# 33/33 - 8s - 246ms/step - loss: 0.0053 - root_mean_squared_error: 0.0725 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 16/150
# 33/33 - 8s - 250ms/step - loss: 0.0052 - root_mean_squared_error: 0.0721 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 17/150
# 33/33 - 8s - 252ms/step - loss: 0.0051 - root_mean_squared_error: 0.0713 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 18/150
# 33/33 - 8s - 255ms/step - loss: 0.0050 - root_mean_squared_error: 0.0707 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0940
# Epoch 19/150
# 33/33 - 9s - 262ms/step - loss: 0.0054 - root_mean_squared_error: 0.0732 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 20/150
# 33/33 - 9s - 260ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 21/150
# 33/33 - 8s - 256ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0939
# Epoch 22/150
# 33/33 - 8s - 252ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0942
# Epoch 23/150
# 33/33 - 8s - 255ms/step - loss: 0.0047 - root_mean_squared_error: 0.0686 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0946
# Epoch 24/150
# 33/33 - 8s - 256ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0922
# Epoch 25/150
# 33/33 - 8s - 254ms/step - loss: 0.0044 - root_mean_squared_error: 0.0665 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0912
# Epoch 26/150
# 33/33 - 8s - 253ms/step - loss: 0.0045 - root_mean_squared_error: 0.0670 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0915
# Epoch 27/150
# 33/33 - 9s - 259ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0904
# Epoch 28/150
# 33/33 - 9s - 274ms/step - loss: 0.0042 - root_mean_squared_error: 0.0652 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0910
# Epoch 29/150
# 33/33 - 9s - 278ms/step - loss: 0.0043 - root_mean_squared_error: 0.0659 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921
# Epoch 30/150
# 33/33 - 9s - 279ms/step - loss: 0.0042 - root_mean_squared_error: 0.0652 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0916
# Epoch 31/150
# 33/33 - 9s - 277ms/step - loss: 0.0041 - root_mean_squared_error: 0.0637 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0935
# Epoch 32/150
# 33/33 - 9s - 276ms/step - loss: 0.0042 - root_mean_squared_error: 0.0648 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0936
# Epoch 33/150
# 33/33 - 9s - 282ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0921
# Epoch 34/150
# 33/33 - 9s - 266ms/step - loss: 0.0041 - root_mean_squared_error: 0.0639 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0925
# Epoch 35/150
# 33/33 - 9s - 259ms/step - loss: 0.0040 - root_mean_squared_error: 0.0636 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 36/150
# 33/33 - 8s - 254ms/step - loss: 0.0040 - root_mean_squared_error: 0.0631 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0916
# Epoch 37/150
# 33/33 - 8s - 251ms/step - loss: 0.0039 - root_mean_squared_error: 0.0624 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
# Epoch 38/150
# 33/33 - 8s - 253ms/step - loss: 0.0039 - root_mean_squared_error: 0.0628 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0933
# Epoch 39/150
# 33/33 - 8s - 254ms/step - loss: 0.0039 - root_mean_squared_error: 0.0626 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0906
# Epoch 40/150
# 33/33 - 8s - 254ms/step - loss: 0.0039 - root_mean_squared_error: 0.0621 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0892
# Epoch 41/150
# 33/33 - 8s - 254ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0906
# Epoch 42/150
# 33/33 - 8s - 252ms/step - loss: 0.0037 - root_mean_squared_error: 0.0608 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 43/150
# 33/33 - 8s - 254ms/step - loss: 0.0038 - root_mean_squared_error: 0.0618 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0890
# Epoch 44/150
# 33/33 - 8s - 255ms/step - loss: 0.0038 - root_mean_squared_error: 0.0614 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0916
# Epoch 45/150
# 33/33 - 8s - 254ms/step - loss: 0.0038 - root_mean_squared_error: 0.0613 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0894
# Epoch 46/150
# 33/33 - 8s - 252ms/step - loss: 0.0037 - root_mean_squared_error: 0.0607 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0913
# Epoch 47/150
# 33/33 - 10s - 311ms/step - loss: 0.0037 - root_mean_squared_error: 0.0611 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0885
# Epoch 48/150
# 33/33 - 8s - 254ms/step - loss: 0.0037 - root_mean_squared_error: 0.0605 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0910
# Epoch 49/150
# 33/33 - 8s - 253ms/step - loss: 0.0037 - root_mean_squared_error: 0.0608 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
# Epoch 50/150
# 33/33 - 9s - 264ms/step - loss: 0.0037 - root_mean_squared_error: 0.0611 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0917
# Epoch 51/150
# 33/33 - 9s - 265ms/step - loss: 0.0037 - root_mean_squared_error: 0.0604 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
# Epoch 52/150
# 33/33 - 9s - 258ms/step - loss: 0.0037 - root_mean_squared_error: 0.0610 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0915
# Epoch 53/150
# 33/33 - 9s - 263ms/step - loss: 0.0036 - root_mean_squared_error: 0.0603 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0888
# Epoch 54/150
# 33/33 - 9s - 266ms/step - loss: 0.0036 - root_mean_squared_error: 0.0597 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0920
# Epoch 55/150
# 33/33 - 9s - 281ms/step - loss: 0.0035 - root_mean_squared_error: 0.0593 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0887
# Epoch 56/150
# 33/33 - 9s - 265ms/step - loss: 0.0035 - root_mean_squared_error: 0.0594 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0882
# Epoch 57/150
# 33/33 - 8s - 254ms/step - loss: 0.0035 - root_mean_squared_error: 0.0592 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0897
# Epoch 58/150
# 33/33 - 8s - 254ms/step - loss: 0.0035 - root_mean_squared_error: 0.0590 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 59/150
# 33/33 - 8s - 254ms/step - loss: 0.0034 - root_mean_squared_error: 0.0587 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0915
# Epoch 60/150
# 33/33 - 8s - 252ms/step - loss: 0.0034 - root_mean_squared_error: 0.0586 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0909
# Epoch 61/150
# 33/33 - 8s - 254ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 62/150
# 33/33 - 8s - 254ms/step - loss: 0.0034 - root_mean_squared_error: 0.0580 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0879
# Epoch 63/150
# 33/33 - 10s - 311ms/step - loss: 0.0035 - root_mean_squared_error: 0.0588 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0897
# Epoch 64/150
# 33/33 - 8s - 253ms/step - loss: 0.0035 - root_mean_squared_error: 0.0592 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0895
# Epoch 65/150
# 33/33 - 8s - 251ms/step - loss: 0.0034 - root_mean_squared_error: 0.0579 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0876
# Epoch 66/150
# 33/33 - 8s - 253ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 67/150
# 33/33 - 8s - 253ms/step - loss: 0.0032 - root_mean_squared_error: 0.0567 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0880
# Epoch 68/150
# 33/33 - 8s - 254ms/step - loss: 0.0033 - root_mean_squared_error: 0.0571 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 69/150
# 33/33 - 8s - 255ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 70/150
# 33/33 - 8s - 251ms/step - loss: 0.0032 - root_mean_squared_error: 0.0568 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 71/150
# 33/33 - 8s - 254ms/step - loss: 0.0032 - root_mean_squared_error: 0.0569 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 72/150
# 33/33 - 8s - 255ms/step - loss: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0884
# Epoch 73/150
# 33/33 - 8s - 254ms/step - loss: 0.0032 - root_mean_squared_error: 0.0567 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 74/150
# 33/33 - 8s - 252ms/step - loss: 0.0031 - root_mean_squared_error: 0.0561 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 75/150
# 33/33 - 8s - 254ms/step - loss: 0.0031 - root_mean_squared_error: 0.0558 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0870
# Epoch 76/150
# 33/33 - 8s - 254ms/step - loss: 0.0032 - root_mean_squared_error: 0.0565 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 77/150
# 33/33 - 8s - 254ms/step - loss: 0.0031 - root_mean_squared_error: 0.0561 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 78/150
# 33/33 - 8s - 252ms/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0873
# Epoch 79/150
# 33/33 - 8s - 254ms/step - loss: 0.0031 - root_mean_squared_error: 0.0555 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 80/150
# 33/33 - 8s - 256ms/step - loss: 0.0031 - root_mean_squared_error: 0.0558 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0879
# Epoch 81/150
# 33/33 - 9s - 259ms/step - loss: 0.0031 - root_mean_squared_error: 0.0559 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 82/150
# 33/33 - 8s - 253ms/step - loss: 0.0031 - root_mean_squared_error: 0.0554 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 83/150
# 33/33 - 8s - 255ms/step - loss: 0.0031 - root_mean_squared_error: 0.0553 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0867
# Epoch 84/150
# 33/33 - 8s - 254ms/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0863
# Epoch 85/150
# 33/33 - 8s - 254ms/step - loss: 0.0031 - root_mean_squared_error: 0.0553 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 86/150
# 33/33 - 8s - 254ms/step - loss: 0.0030 - root_mean_squared_error: 0.0552 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0871
# Epoch 87/150
# 33/33 - 8s - 253ms/step - loss: 0.0031 - root_mean_squared_error: 0.0552 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 88/150
# 33/33 - 8s - 255ms/step - loss: 0.0031 - root_mean_squared_error: 0.0556 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 89/150
# 33/33 - 8s - 254ms/step - loss: 0.0030 - root_mean_squared_error: 0.0548 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 90/150
# 33/33 - 8s - 254ms/step - loss: 0.0031 - root_mean_squared_error: 0.0555 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 91/150
# 33/33 - 9s - 267ms/step - loss: 0.0031 - root_mean_squared_error: 0.0553 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0863
# Epoch 92/150
# 33/33 - 8s - 255ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 93/150
# 33/33 - 8s - 255ms/step - loss: 0.0030 - root_mean_squared_error: 0.0545 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 94/150
# 33/33 - 8s - 254ms/step - loss: 0.0029 - root_mean_squared_error: 0.0541 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 95/150
# 33/33 - 8s - 252ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0868
# Epoch 96/150
# 33/33 - 8s - 254ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 97/150
# 33/33 - 8s - 254ms/step - loss: 0.0030 - root_mean_squared_error: 0.0544 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 98/150
# 33/33 - 8s - 255ms/step - loss: 0.0029 - root_mean_squared_error: 0.0541 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 99/150
# 33/33 - 8s - 254ms/step - loss: 0.0030 - root_mean_squared_error: 0.0548 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0869
# Epoch 100/150
# 33/33 - 8s - 252ms/step - loss: 0.0030 - root_mean_squared_error: 0.0545 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0856
# Epoch 101/150
# 33/33 - 8s - 255ms/step - loss: 0.0030 - root_mean_squared_error: 0.0543 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0869
# Epoch 102/150
# 33/33 - 8s - 254ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 103/150
# 33/33 - 8s - 254ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852
# Epoch 104/150
# 33/33 - 9s - 259ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0893
# Epoch 105/150
# 33/33 - 8s - 255ms/step - loss: 0.0028 - root_mean_squared_error: 0.0533 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 106/150
# 33/33 - 8s - 254ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 107/150
# 33/33 - 9s - 264ms/step - loss: 0.0029 - root_mean_squared_error: 0.0541 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 108/150
# 33/33 - 9s - 264ms/step - loss: 0.0029 - root_mean_squared_error: 0.0537 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 109/150
# 33/33 - 8s - 255ms/step - loss: 0.0029 - root_mean_squared_error: 0.0538 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 110/150
# 33/33 - 8s - 254ms/step - loss: 0.0029 - root_mean_squared_error: 0.0535 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 111/150
# 33/33 - 8s - 257ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 112/150
# 33/33 - 9s - 271ms/step - loss: 0.0029 - root_mean_squared_error: 0.0540 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0882
# Epoch 113/150
# 33/33 - 10s - 314ms/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0855
# Epoch 114/150
# 33/33 - 9s - 275ms/step - loss: 0.0028 - root_mean_squared_error: 0.0531 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 115/150
# 33/33 - 9s - 271ms/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0866
# Epoch 116/150
# 33/33 - 9s - 263ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0875
# Epoch 117/150
# 33/33 - 9s - 258ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0861
# Epoch 118/150
# 33/33 - 8s - 254ms/step - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 119/150
# 33/33 - 8s - 250ms/step - loss: 0.0027 - root_mean_squared_error: 0.0524 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0863
# Epoch 120/150
# 33/33 - 8s - 252ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 121/150
# 33/33 - 8s - 253ms/step - loss: 0.0028 - root_mean_squared_error: 0.0532 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0848
# Epoch 122/150
# 33/33 - 8s - 253ms/step - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0869
# Epoch 123/150
# 33/33 - 8s - 252ms/step - loss: 0.0028 - root_mean_squared_error: 0.0529 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 124/150
# 33/33 - 9s - 270ms/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 125/150
# 33/33 - 9s - 259ms/step - loss: 0.0028 - root_mean_squared_error: 0.0533 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0850
# Epoch 126/150
# 33/33 - 8s - 254ms/step - loss: 0.0028 - root_mean_squared_error: 0.0526 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 127/150
# 33/33 - 8s - 255ms/step - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0847
# Epoch 128/150
# 33/33 - 8s - 252ms/step - loss: 0.0028 - root_mean_squared_error: 0.0528 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0857
# Epoch 129/150
# 33/33 - 8s - 253ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 130/150
# 33/33 - 8s - 253ms/step - loss: 0.0028 - root_mean_squared_error: 0.0524 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0853
# Epoch 131/150
# 33/33 - 8s - 254ms/step - loss: 0.0027 - root_mean_squared_error: 0.0523 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 132/150
# 33/33 - 8s - 252ms/step - loss: 0.0027 - root_mean_squared_error: 0.0522 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0858
# Epoch 133/150
# 33/33 - 8s - 255ms/step - loss: 0.0027 - root_mean_squared_error: 0.0524 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0872
# Epoch 134/150
# 33/33 - 8s - 254ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865
# Epoch 135/150
# 33/33 - 8s - 254ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0874
# Epoch 136/150
# 33/33 - 9s - 258ms/step - loss: 0.0027 - root_mean_squared_error: 0.0522 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0862
# Epoch 137/150
# 33/33 - 9s - 275ms/step - loss: 0.0027 - root_mean_squared_error: 0.0518 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 138/150
# 33/33 - 9s - 279ms/step - loss: 0.0028 - root_mean_squared_error: 0.0530 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 139/150
# 33/33 - 9s - 279ms/step - loss: 0.0027 - root_mean_squared_error: 0.0515 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
# Epoch 140/150
# 33/33 - 9s - 281ms/step - loss: 0.0027 - root_mean_squared_error: 0.0516 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0863
# Epoch 141/150
# 33/33 - 9s - 277ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
# Epoch 142/150
# 33/33 - 9s - 275ms/step - loss: 0.0027 - root_mean_squared_error: 0.0520 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 143/150
# 33/33 - 9s - 272ms/step - loss: 0.0026 - root_mean_squared_error: 0.0514 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 144/150
# 33/33 - 9s - 266ms/step - loss: 0.0027 - root_mean_squared_error: 0.0516 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 145/150
# 33/33 - 9s - 260ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0859
# Epoch 146/150
# 33/33 - 9s - 264ms/step - loss: 0.0026 - root_mean_squared_error: 0.0512 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0852
# Epoch 147/150
# 33/33 - 8s - 252ms/step - loss: 0.0026 - root_mean_squared_error: 0.0507 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0860
# Epoch 148/150
# 33/33 - 8s - 254ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0857
# Epoch 149/150
# 33/33 - 8s - 254ms/step - loss: 0.0026 - root_mean_squared_error: 0.0511 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0863
# Epoch 150/150
# 33/33 - 8s - 254ms/step - loss: 0.0027 - root_mean_squared_error: 0.0519 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0865

# %% [markdown]
# After fitting our training set with the model, we can evaluate whether our model overfits the training set or not. One way of doing it is by plotting the loss functions at each step of the training.

# %%
def plot_training(training_history, text, width):
    history = training_history.history[text]
    
    # creates a moving average plot to reduce variations
    moving_average = [float("NaN") for i in range(width)]
    for i in range(width, len(history)+1):
        moving_average.append(np.mean(np.array(history[i-width:i+1])))
        
    plt.plot(history)
    plt.plot(moving_average)
    plt.title(text)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['value','moving average'], loc='upper left')
    plt.show()

# %%
# Plots the loss (MSE and RMSE) of both test and validation data
WIDTH = 10
plot_training(history,'loss',WIDTH)
plot_training(history,'val_loss',WIDTH)
plot_training(history,'val_root_mean_squared_error',WIDTH)
plot_training(history,'root_mean_squared_error',WIDTH)

# %% [markdown]
# We can observe that the validation loss value flattening after 120 epochs of training, despite that the training loss keep decreasing. If the training keeps going, our model would overfit to the training set (lower training loss but higher validation loss). In order to avoid those issues, it is best that we would limit the number of training epochs to around that value, which is 150 epochs for this case.

# %% [markdown]
# <a id="section-7"></a>
# # Evaluate Prediction

# %% [markdown]
# Now time to evaluate how good our model is. We add a moving average as the baseline. The reason we need a baseline is to see whether our RMSE score and Spearman score is actually good, not just due to random guessing.

# %%
def predict_and_calc_score(X, Y):
    # prediction of Y using the model
    pred = model.predict(X) 
    # moving average of Y
    window_size = 12
    moving_average = np.apply_along_axis(
        lambda x: np.convolve(x, np.ones(window_size)/window_size, mode='same'), axis=0, arr=Y)
    moving_average = np.concatenate((np.zeros((1, Y.shape[1])), moving_average), axis=0)[:Y.shape[0]]
    
    # scale it back to the original scale
    pred_scaled = scaler_Y.inverse_transform(pred)
    moving_average_scaled = scaler_Y.inverse_transform(moving_average)
    Y_scaled = scaler_Y.inverse_transform(Y)
    
    # calculate the RMSE
    baseline_RMSE = np.sqrt(np.mean((Y_scaled - moving_average_scaled) ** 2))
    model_RMSE = np.sqrt(np.mean((Y_scaled - pred_scaled) ** 2))
    
    return Y_scaled, pred_scaled, moving_average_scaled, model_RMSE, baseline_RMSE

def plot_prediction(actual, prediction, moving_average):
    # Plot the actual values
    plt.plot(actual, label="True value", linestyle='-', linewidth=1, marker='s', markersize=1)
    
    # Plot the moving average
    plt.plot(moving_average, label="Moving Average", linestyle='--', linewidth=1, marker='s', markersize=1)
    
    # Plot the predicted values
    plt.plot(prediction, label="Prediction", linestyle='--', linewidth=1, marker='o', markersize=1)
    
    # Set the title and axis labels
    plt.title('Prediction vs. True Value', fontsize=16)
    plt.xlabel('Hour Timesteps')
    plt.ylabel('Output Value')

    # Add a legend to the plot
    plt.legend(loc='upper left', fontsize=12)
    
    # Display the plot
    plt.show()

# %%
train_actual, train_prediction, train_moving_average, train_RMSE, baseline_RMSE = \
    predict_and_calc_score(train_X, train_Y)

print("Train Moving Average RMSE:", baseline_RMSE)
print("Train Prediction RMSE:", train_RMSE)

corr, pval = stats.spearmanr(train_actual, train_moving_average)
mov_spearman_corr = np.mean(corr)
corr, pval = stats.spearmanr(train_actual, train_prediction)
pred_spearman_corr = np.mean(corr)

print("Train Moving Average Spearman Correlation:", mov_spearman_corr)
print("Train Prediction Spearman Correlation:", pred_spearman_corr)
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step
# Train Moving Average RMSE: 0.02385027817581988
# Train Prediction RMSE: 0.014440290191882251
# Train Moving Average Spearman Correlation: 0.715110464085153
# Train Prediction Spearman Correlation: 0.8020590133383892

# %%
location = 3
plot_prediction(train_actual[:,location], train_prediction[:,location], train_moving_average[:,location])

# %% [markdown]
# The train RMSE and Spearman is good. It is better than the moving average and shows that the model is not underfitting. However, the true test lies on the test evaluation (since Neural Network models might overfit).

# %%
test_actual, test_prediction, test_moving_average, test_RMSE, baseline_RMSE = \
    predict_and_calc_score(test_X, test_Y)

print("Test Moving Average RMSE:", baseline_RMSE)
print("Test Prediction RMSE:", test_RMSE)

corr, pval = stats.spearmanr(test_actual, test_moving_average)
mov_spearman_corr = np.mean(corr)
corr, pval = stats.spearmanr(test_actual, test_prediction)
pred_spearman_corr = np.mean(corr)

print("Test Moving Average Spearman Correlation:", mov_spearman_corr)
print("Test Prediction Spearman Correlation:", pred_spearman_corr)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# Test Moving Average RMSE: 0.026519227318993185
# Test Prediction RMSE: 0.01938463919598828
# Test Moving Average Spearman Correlation: 0.7208930441211854
# Test Prediction Spearman Correlation: 0.8155204234240829

# %%
location = 10
plot_prediction(test_actual[:,location], test_prediction[:,location], test_moving_average[:,location])

# %% [markdown]
# The test RMSE and Spearman is also good! It is better than the moving average and shows that the model is not overfitting and can generalize well to new data.

# %%
model.save('LSTM_model.keras')

# %% [markdown]
# Finally, we can also save the model.

# %% [markdown]
# <a id="section-8"></a>
# # Conclusion

# %% [markdown]
# To conclude, we have made a predictive model using an LSTM neural network. We included hour and lag features, and also carefully scale and split the data. In the end, our model was able to predict both the train and test data better than our baseline which is moving average of previous values. We believe that this model can be further optimized and tested to help solve one of the real world issues, which is traffic management.

# %% [markdown]
# # Limitations and Improvements

# %% [markdown]
# Although your model outperforms the baseline, there are several areas for improvement:
#
# 1. **Decrease Time Interval**: Converting the data from a 5-minute interval to a 60-minute interval may sacrifice specific details. However, reducing the time interval might improve the model's performance by capturing finer-grained patterns in the data. If hardware limitations allow, consider using smaller time intervals to obtain more detailed data.
#
# 2. **Increase Lag Steps**: Including more lag steps in the model has the potential to improve its accuracy. Although memory limitations prevented the use of higher time steps, increasing the number of lag steps could enhance the model's ability to capture temporal dependencies.
#
# 3. **Vanishing Gradient Problem**: As the model utilizes more hidden layers and lag steps, the adjustment of weights in earlier layers during backpropagation may become insignificant, hindering performance. This issue, known as the vanishing gradient problem, is common in LSTM layers. Consider addressing this issue by implementing attention mechanisms, which can help the model focus on relevant input data for each prediction, thereby improving performance.
#
# In summary, optimizing the time interval, increasing lag steps, and addressing the vanishing gradient problem with attention mechanisms could enhance the performance of your model.
